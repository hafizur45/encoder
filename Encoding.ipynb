# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizur45/encoder/blob/main/Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Copy of supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df['Transport']=df['Transport'].fillna(df.Transport.mean())

# %%
df
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 0         114523.61       136897.80  471784.100000    Dhaka  192261.83
# 1         162597.70       151377.59  443898.530000      Ctg  191792.06
# 2         153441.51       101145.55  407934.540000  Rangpur  191050.39
# 3         144372.41       118671.85  383199.620000    Dhaka  182901.99
# 4         142107.34        91391.77  366168.420000  Rangpur  166187.94
# 5         131876.90        99814.71  362861.360000    Dhaka  156991.12
# 6         134615.46       147198.87  127716.820000      Ctg  156122.51
# 7         130298.13       145530.06  323876.680000  Rangpur  155752.60
# 8         120542.52       148718.95  311613.290000    Dhaka  152211.77
# 9         123334.88       108679.17  304981.620000      Ctg  149759.96
# 10        101913.08       110594.11  229160.950000  Rangpur  146121.95
# 11        100671.96        91790.61  249744.550000      Ctg  144259.40
# ...

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        50 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df2=df.copy()
df3=df.copy()
df4=df.copy()
df5=df.copy()

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# Label Encoding

# %%
df2.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder as le

# %%
l=le()

# %%
df2['Area'] = l.fit_transform(df2.Area)

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# Using Loop label Encoder

# %%
for col in df3.columns:
  if col != np.number:
    df3[col]= l.fit_transform(df3[col])

# %%
df3.Area.unique()
# Out:
# array([1, 0, 2])

# %% [markdown]
# onehotencoding

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import OneHotEncoder as oe

# %%
o=oe()
df4.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
dummies = pd.get_dummies(df4['Area'])

# %%
dummies
# Out:
#     Ctg  Dhaka  Rangpur
# 0     0      1        0
# 1     1      0        0
# 2     0      0        1
# 3     0      1        0
# 4     0      0        1
# 5     0      1        0
# 6     1      0        0
# 7     0      0        1
# 8     0      1        0
# 9     1      0        0
# 10    0      0        1
# 11    1      0        0
# 12    0      0        1
# 13    1      0        0
# 14    0      0        1
# 15    0      1        0
# 16    1      0        0
# 17    0      1        0
# 18    0      0        1
# 19    0      1        0
# 20    1      0        0
# 21    0      1        0
# 22    0      0        1
# 23    0      0        1
# 24    0      1        0
# 25    1      0        0
# 26    0      0        1
# 27    0      1        0
# 28    0      0        1
# 29    0      1        0
# 30    0      0        1
# 31    0      1        0
# 32    1      0        0
# 33    0      0        1
# 34    1      0        0
# 35    0      1        0
# 36    0      0        1
# ...

# %%
df5.drop('Area',axis=1)
# Out:
#     Marketing Spend  Administration      Transport     Profit
# 0         114523.61       136897.80  471784.100000  192261.83
# 1         162597.70       151377.59  443898.530000  191792.06
# 2         153441.51       101145.55  407934.540000  191050.39
# 3         144372.41       118671.85  383199.620000  182901.99
# 4         142107.34        91391.77  366168.420000  166187.94
# 5         131876.90        99814.71  362861.360000  156991.12
# 6         134615.46       147198.87  127716.820000  156122.51
# 7         130298.13       145530.06  323876.680000  155752.60
# 8         120542.52       148718.95  311613.290000  152211.77
# 9         123334.88       108679.17  304981.620000  149759.96
# 10        101913.08       110594.11  229160.950000  146121.95
# 11        100671.96        91790.61  249744.550000  144259.40
# 12         93863.75       127320.38  249839.440000  141585.52
# 13         91992.39       135495.07  252664.930000  134307.35
# ...

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df5=pd.concat((df5,dummies),axis=1)

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  Ctg  Dhaka  \
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83    0      1
# 1        162597.70       151377.59  443898.53      Ctg  191792.06    1      0
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39    0      0
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99    0      1
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94    0      0
#
#    Rangpur
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# onehotencoder using loop

# %%
df6=df.copy()
df7=df.copy()
df8=df.copy()

# %%
for col in df6.columns:
  if df[col].dtypes !=np.number:
    dum=pd.get_dummies(df6[col],prefix='one hot area')
    df6.drop(col,inplace=True,axis=1)
    df6=pd.concat((df6,dum),axis=1)
# Out:
# <ipython-input-86-65e9cdf637de>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[col].dtypes !=np.number:
# <ipython-input-86-65e9cdf637de>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[col].dtypes !=np.number:

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  one hot area_Ctg  \
# 0        114523.61       136897.80  471784.10  192261.83                 0
# 1        162597.70       151377.59  443898.53  191792.06                 1
# 2        153441.51       101145.55  407934.54  191050.39                 0
# 3        144372.41       118671.85  383199.62  182901.99                 0
# 4        142107.34        91391.77  366168.42  166187.94                 0
#
#    one hot area_Dhaka  one hot area_Rangpur
# 0                   1                     0
# 1                   0                     0
# 2                   0                     1
# 3                   1                     0
# 4                   0                     1

# %% [markdown]
# Ordinal Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder as ore

# %%
ordinal = ore()
df7.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df7[['Area New']] = ordinal.fit_transform(df7[['Area']])

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  Area New
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83       1.0
# 1        162597.70       151377.59  443898.53      Ctg  191792.06       0.0
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39       2.0
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99       1.0
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94       2.0

# %% [markdown]
# Using Loop

# %%
for col in df8.columns:
  if  df8[col].dtypes != np.number:
    ordinalloop = ore()
    df8[[col]] = ordinalloop.fit_transform( df8[[col]])
# Out:
# <ipython-input-103-d5a7c6e99e8c>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if  df8[col].dtypes != np.number:
# <ipython-input-103-d5a7c6e99e8c>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if  df8[col].dtypes != np.number:

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   1.0  192261.83
# 1        162597.70       151377.59  443898.53   0.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   1.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94
